# %%
from pathlib import Path
import typer
import numpy as np
import os
import sys
import torch
from torch.utils.data import Dataset
print(os.getcwd())
# Out:
# /home/gabriel/MyFiles/DTU_code/MLOPS/dtu-mlops-garu

# %%
class MyDataset(Dataset):
    """My custom dataset."""

    def __init__(self, data_path: Path) -> None:
        self.data_path = data_path

    def __len__(self) -> int:
        """Return the length of the dataset."""

    def __getitem__(self, index: int):
        """Return a given sample from the dataset."""

    def preprocess(self, output_folder: Path) -> None:
        """Preprocess the raw data and save it to the output folder."""

# %%
data_dir = Path("data") / "corruptmnist"
data_path1 = data_dir / "train_images_1.pt"
for p in sorted(data_dir.iterdir()):
    if p.is_file():
        print(p.name)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 3
#       1 data_dir = Path("data") / "corruptmnist"
#       2 data_path1 = data_dir / "train_images_1.pt"
# ----> 3 for p in sorted(data_dir.iterdir()):
#       4     if p.is_file():
#       5         print(p.name)
#
# File /usr/lib/python3.12/pathlib.py:1058, in Path.iterdir(self)
#    1052 def iterdir(self):
#    1053     """Yield path objects of the directory contents.
#    1054
#    1055     The children are yielded in arbitrary order, and the
#    1056     special entries '.' and '..' are not included.
#    1057     """
# -> 1058     for name in os.listdir(self):
#    1059         yield self._make_child_relpath(name)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/corruptmnist'

# %%
import matplotlib.pyplot as plt
img = torch.load(f = data_path1)
img.shape # 5000 images in each batch
img.shape
data_path5 = data_dir / "train_images_1.pt"
img = torch.load(f = data_path5)
img.shape # 5000 images in each batch
# Out:
# torch.Size([5000, 28, 28])

# %%
def imshow(image, ax=None, title=None, normalize=True):
    """Imshow for Tensor."""
    if ax is None:
        fig, ax = plt.subplots()
    image = image.numpy().transpose((1, 2, 0))

    # Sets standard for how to normalize tensor images
    if normalize:
        mean = np.array([0.485, 0.456, 0.406])
        std = np.array([0.229, 0.224, 0.225])
        image = std * image + mean
        image = np.clip(image, 0, 1)

    ax.imshow(image)
    ax.spines["top"].set_visible(False)
    ax.spines["right"].set_visible(False)
    ax.spines["left"].set_visible(False)
    ax.spines["bottom"].set_visible(False)
    ax.tick_params(axis="both", length=0)
    ax.set_xticklabels("")
    ax.set_yticklabels("")

    return ax

for i in range(10):
    imshow(torch.unsqueeze(img[i], 0), normalize=False)

# %%
import torch
a = torch.randn(4, 4, 4)
a.mean((1,2))
# Out:
# tensor([-0.3985,  0.1692, -0.0226,  0.0299])
